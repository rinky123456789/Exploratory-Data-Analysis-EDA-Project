# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/student_performance_eda.csv")

# View first 5 rows
print(data.head())
# Out:
#    Student_ID  Gender  StudyHours  Attendance  SleepHours  PracticePapers  \
# 0           1    Male           7          76           6               0
# 1           2  Female           7          92           4               4
# 2           3    Male           1          71           6               8
# 3           4    Male           4          81           7               0
# 4           5    Male           5          81           5               2
#
#   InternetAccess  FinalScore
# 0            Yes        82.0
# 1             No        77.0
# 2            Yes        51.0
# 3             No        62.0
# 4            Yes        65.0

# %%
# Dataset information
print(data.info())

# Statistical summary
print(data.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Student_ID      200 non-null    int64
#  1   Gender          200 non-null    object
#  2   StudyHours      200 non-null    int64
#  3   Attendance      200 non-null    int64
#  4   SleepHours      200 non-null    int64
#  5   PracticePapers  200 non-null    int64
#  6   InternetAccess  200 non-null    object
#  7   FinalScore      200 non-null    float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 12.6+ KB
# None
#        Student_ID  StudyHours  Attendance  SleepHours  PracticePapers  \
# count  200.000000  200.000000   200.00000  200.000000      200.000000
# mean   100.500000    3.800000    81.10000    6.105000        4.455000
# std     57.879185    2.012524    11.42157    1.501749        2.889589
# ...

# %%
print(data.isnull().sum())
# Out:
# Student_ID        0
# Gender            0
# StudyHours        0
# Attendance        0
# SleepHours        0
# PracticePapers    0
# InternetAccess    0
# FinalScore        0
# dtype: int64

# %%
print("Duplicate rows:", data.duplicated().sum())

# Remove duplicates if any
data = data.drop_duplicates()
# Out:
# Duplicate rows: 0

# %%
data.hist(figsize=(10,8))
plt.show()

# %%
sns.countplot(x="Gender", data=data)
plt.title("Gender Distribution")
plt.show()

# %%
sns.scatterplot(x="StudyHours", y="FinalScore", data=data)
plt.title("Study Hours vs Final Score")
plt.show()

# %%
sns.scatterplot(x="Attendance", y="FinalScore", data=data)
plt.title("Attendance vs Final Score")
plt.show()

# %%
sns.scatterplot(x="PracticePapers", y="FinalScore", data=data)
plt.title("Practice Papers vs Final Score")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(data.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.boxplot(x=data["FinalScore"])
plt.title("Outliers in Final Score")
plt.show()
